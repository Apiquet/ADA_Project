# %% [markdown]
# # ADA Project
# <br><br>
#
# ----
# ### Subject:
# finding what influence the number of protests among: area of the country, population density, net migration, infant mortality, deathrate, income group, climate, etc.
# <br><br>
#
# ----
# ### Objective:
# finding what to change in a country to decrease the number of protests (assuming that a less number of protests means that the inhabitants are happier)
# <br><br>
#
# ----
# ### Summary:
# First, we will get all the data we need. Second we will find a way to display data on a world map to visualize the number of protests around the world. Then, we will try to find the impact of many variables on this number of protests.
# <br><br>
#
# ----
# ### Data explanations:
# Please see the read me, section Dataset / 4- Data description to see data explanations
#
# Here a brief explanation:
#
# We are using the data available at the following link: https://bigquery.cloud.google.com/table/gdelt-bq:gdeltv2.events This is a context of **big data**: around **400 000 000** of rows.
# <br><br>
# - ##### <u>eventcodes.csv</u>
#
# As we are interested in protest as kind of event, we need to find the event code associated to the protest events: **eventcodes.csv** gives us this data.
# <br><br>
# - ##### <u>country_by_income.csv and countries_stats.csv</u>
#
# Then, we need to get data on all the countries to find the impact of their characteristics on the number of protests: **country_by_income.csv** and **countries_stats.csv** give us what we need. Thanks to these files, we have access to: the average income, area of the country, population density, net migration, infant mortality, deathrate, climate, etc of each country.
# Got from: http://datatopics.worldbank.org/world-development-indicators/the-world-by-income-and-region.html and https://www.kaggle.com/fernandol/countries-of-the-world/version/1
#
# <br><br>
# Let's see the **countries_stats.csv** file:
#
# data got from: https://www.kaggle.com/fernandol/countries-of-the-world/version/1
#
# Data available: `Country`, `Region`, `Population`, `Area (sq. mi.)`, `Pop. Density (per sq. mi.)`, `Coastline (coast/area ratio)`, `Net migration`, `Infant mortality (per 1000 births)`, `GDP ($ per capita)`, `Literacy (%)`, `Phones (per 1000)`, `Arable (%)`, `Crops (%)`, `Other (%)`, `Climate`, `Birthrate`, `Deathrate`, `Agriculture`, `Industry`, `Service`.
#
# Most of the variables don't need to be explain as `population`, `Area (sq. mi.)`, `Infant mortality`, etc. As we wordered the meaning of `climate`, here the explanation we found:
#
# Meaning of `climate`: 1= Dry tropical, 2= Wet tropical, 3= Temperate humid subtropical and temperate continental, 4= Dry hot summers and wet winters
# <br><br>
# - ##### <u>country_codes_iso2_to_iso3.csv and country_code_to_name.csv</u>
#
# Each data define the country in a different way: code in `ISO2` or `ISO3` or with the `country name`. We need to convert each ones with the same convention. For example, to define the United-States of America, the csv files use "USA", "US" or "United-States of America".
# **country_codes_iso2_to_iso3.csv** and **country_code_to_name.csv** allow us to achieve these conversions.
# there are from: https://github.com/lukes/ISO-3166-Countries-with-Regional-Codes/blob/master/all/all.csv
# <br><br>
#
# - ##### <u>GDP growth world bank.csv and GINI per country worldbank.csv</u> (<a> https://data.worldbank.org </a>)
# These two dataset are the estimations of the Gross Domestic Product (GDP) and the Index of Inequality (GINI) for each country , from 1960 to 2017. These datasets will be usefull economical and social indicator to understand the protestation in different countries.
#
#
# - ##### <u>DataCorruptionPerceptionIndex2000_2017.xlsx</u> (<a>https://www.transparency.org</a>)
# This data set shows the estimated Corruption index (political and buisness corruption) for each country from 1998 to 2015.
#
#
# - ##### <u>Human Development Index (HDI).csv</u> (<a> http://hdr.undp.org/en/data </a>)
# Dataset of the HDI for each country from 1990 to 2017.
# HDI a good indicator of the life expectancy and education of people in the country.
# The definition of HDI from wikipedia:
# "The Human Development Index (HDI) is a statistic composite index of life expectancy, education, and per capita income indicators"
#
#
#
# - ##### <u>World press freedom.csv
# </u> (<a> https://rsf.org/fr/donnees-classement </a>)(<a> https://en.wikipedia.org/wiki/Press_Freedom_Index </a>)
#
# This data-set shows the score of each country concerning the press freedom from 2002 to 2018
#
#
#
# ----
# ### Next steps until Dec. 16
# Please see the read me, section "A list of internal milestones until Dec. 16" or the end of the notebook as asked here: https://dlab.epfl.ch/teaching/fall2018/cs401/projects/

# %%
from google.cloud import bigquery
import pandas as pd
import numpy as np
import os
import json
import folium
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
from sklearn.linear_model import LinearRegression, LogisticRegression
from branca.colormap import linear

DATA_PATH = "data/"
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = 'C:\\Users\\antho\\Downloads\\ADAproj-02b470a29ee4.json'#
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = 'C:\\Users\\bot_\\Downloads\\AdaProject-3323118f7315.json'
# get json by following (Setting up authentication)
# https://cloud.google.com/bigquery/docs/reference/libraries

# %%
bigquery_client = bigquery.Client()

# %% [markdown]
# # Getting the main tables:
#
# - event codes table
# - indication of richness per inhabitant per country
# - Protests for leadership change
# - Protests for rights
# - country codes table
# - country codes conversion iso2 to iso3
# - statistics on countries

# %% [markdown]
# ### Event codes:

# %%
event_codes = pd.read_csv(DATA_PATH + "eventcodes.csv", encoding = "ISO-8859-1")

# %%
event_codes[event_codes['EVENTDESCRIPTION'].str.contains('leadership change')]
# Out:
#      CAMEOEVENTCODE                                   EVENTDESCRIPTION
# 223            1411                  Demonstrate for leadership change
# 228            1421        Conduct hunger strike for leadership change
# 233            1431  Conduct strike or boycott for leadership change
# 238            1441      Obstruct passage to demand leadership change
# 243            1451  Engage in violent protest for leadership change

# %%
event_codes[event_codes['EVENTDESCRIPTION'].str.contains('for rights')]
# Out:
#      CAMEOEVENTCODE                      EVENTDESCRIPTION
# 27              243                     Appeal for rights
# 109             833          Accede to demands for rights
# 183            1233             Reject request for rights
# 225            1413                Demonstrate for rights
# 230            1423      Conduct hunger strike for rights
# 235            1433  Conduct strike or boycott for rights
# 245            1453  Engage in violent protest for rights

# %% [markdown]
# ### Indication of richness per inhabitant per country per year:

# %%
country_by_income_per_year = pd.read_csv(DATA_PATH + "country_by_income.csv", encoding = "ISO-8859-1")

# %%
country_by_income_per_year.head()
# Out:
#   Country Code                Economy              Income Group  Year  \
# 0          ZWE               Zimbabwe  Lower middle income (LM)  1987
# 1          ZMB                 Zambia            Low income (L)  1987
# 2          YEM            Yemen, Rep.  Lower middle income (LM)  1987
# 3          PSE     West Bank and Gaza                       NaN  1987
# 4          VIR  Virgin Islands (U.S.)           High income (H)  1987
#
#   Latitude Longitude
# 0  -19,098    30,047
# 1   -15,13    25,268
# 2   15,569    47,793
# 3   32,097     35,26
# 4    17,74     -64,8

# %%
country_by_income_per_year=country_by_income_per_year.dropna()
#here we only get an indicator of the income, we need to transform it to process it
#we choose to transform Low income (L) to 1, (LM) to 3, (UM) to 4, (H) to 6
country_by_income_per_year=country_by_income_per_year.replace('Low income (L)', '1')
country_by_income_per_year=country_by_income_per_year.replace('Lower middle income (LM)', '3')
country_by_income_per_year=country_by_income_per_year.replace('Upper middle income (UM)', '4')
country_by_income_per_year=country_by_income_per_year.replace('High income (H)', '6')
country_by_income_per_year['Income Group']=country_by_income_per_year['Income Group'].astype(int)
country_by_income_per_year['Income Group'].unique()
# Out:
# array([3, 1, 6, 4], dtype=int64)

# %% [markdown]
# ### Getting protests events (for rights, for leadership change, etc):

# %%
query_protests = bigquery_client.query(
    """SELECT ActionGeo_CountryCode, Actor1CountryCode, Actor1Geo_Lat, Actor1Geo_Long, AvgTone FROM `gdelt-bq.gdeltv2.events` 
    WHERE EventCode LIKE '14%' AND EventCode NOT LIKE '140' AND EventCode NOT LIKE '141'""")
protests_df = query_protests.result().to_dataframe()
protests_df=protests_df.dropna()

# %%
#Displaying number of protests available in the data
protests_df.count()
# Out:
# ActionGeo_CountryCode    336779
# Actor1CountryCode        336779
# Actor1Geo_Lat            336779
# Actor1Geo_Long           336779
# AvgTone                  336779
# dtype: int64

# %%
type(protests_df)
# Out:
# pandas.core.frame.DataFrame

# %%
protests_df['Actor1CountryCode'].unique()
# Out:
# array(['ABW', 'AFG', 'AFR', 'AGO', 'AIA', 'ALB', 'AND', 'ARE', 'ARG',
#        'ARM', 'ASA', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN',
#        'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BLR', 'BLZ', 'BMU', 'BOL',
#        'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COK', 'COL', 'COM', 'CPV',
#        'CRB', 'CRI', 'CUB', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA',
#        'DNK', 'DOM', 'DZA', 'EAF', 'ECU', 'EGY', 'ERI', 'ESP', 'EST',
#        'ETH', 'EUR', 'FIN', 'FJI', 'FRA', 'FSM', 'GAB', 'GBR', 'GEO',
#        'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GTM', 'GUY',
#        'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IND', 'IRL', 'IRN',
#        'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN',
#        'KGZ', 'KHM', 'KNA', 'KOR', 'KWT', 'LAM', 'LAO', 'LBN', 'LBR',
#        'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAR',
#        'MCO', 'MDA', 'MDG', 'MDV', 'MEA', 'MEX', 'MHL', 'MKD', 'MLI',
#        'MLT', 'MMR', 'MNG', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', 'NAM',
#        'NER', 'NGA', 'NIC', 'NLD', 'NMR', 'NOR', 'NPL', 'NRU', 'NZL',
#        'OMN', 'PAK', 'PAN', 'PER', 'PGS', 'PHL', 'PLW', 'PNG', 'POL',
#        'PRK', 'PRT', 'PRY', 'PSE', 'QAT', 'ROM', 'RUS', 'RWA', 'SAF',
#        'SAS', 'SAU', 'SDN', 'SEA', 'SEN', 'SGP', 'SHN', 'SLB', 'SLE',
#        'SLV', 'SMR', 'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SWE',
#        'SWZ', 'SYC', 'SYR', 'TCD', 'TGO', 'THA', 'TJK', 'TKM', 'TMP',
#        'TON', 'TTO', 'TUN', 'TUR', 'TWN', 'TZA', 'UGA', 'UKR', 'URY',
#        'USA', 'UZB', 'VAT', 'VCT', 'VEN', 'VNM', 'VUT', 'WAF', 'WLF',
#        'WSM', 'WST', 'YEM', 'ZAF', 'ZMB', 'ZWE'], dtype=object)

# %%
protests_df['ActionGeo_CountryCode'].unique()
# Out:
# array(['SP', 'AA', 'NL', 'MO', 'AF', 'FR', 'UK', 'NI', 'GM', 'NO', 'TI',
#        'DA', 'SW', 'LY', 'UP', 'GR', 'JO', 'IZ', 'SY', 'PK', 'KE', 'US',
#        'MX', 'TX', 'CU', 'RS', 'ID', 'GH', 'IS', 'UV', 'SA', 'IN', 'AS',
#        'BU', 'BG', 'IC', 'ML', 'MK', 'CH', 'MG', 'JA', 'UZ', 'CY', 'TU',
#        'DJ', 'IR', 'BR', 'CA', 'YM', 'BT', 'GB', 'RI', 'KS', 'TH', 'BE',
#        'VM', 'IT', 'KG', 'RO', 'SZ', 'AE', 'KN', 'HU', 'RP', 'KU', 'QA',
#        'NR', 'AM', 'RB', 'SF', 'NG', 'BY', 'BN', 'AG', 'TS', 'SG', 'IV',
#        'UG', 'PO', 'EI', 'SE', 'LI', 'EK', 'GV', 'SL', 'CM', 'CF', 'CG',
#        'EZ', 'GA', 'WA', 'OD', 'CT', 'ZI', 'BC', 'MP', 'HA', 'LH', 'CE',
#        'SO', 'AO', 'ZA', 'RW', 'TZ', 'EG', 'ET', 'SU', 'MI', 'GL', 'NS',
#        'AR', 'CO', 'BF', 'PE', 'PM', 'HK', 'ER', 'WZ', 'MZ', 'MA', 'MB',
#        'VE', 'CD', 'LT', 'TO', 'SN', 'AU', 'PU', 'MU', 'KZ', 'LU', 'MR',
#        'GP', 'VI', 'LE', 'JE', 'LG', 'AL', 'BM', 'EC', 'NZ', 'TP', 'AV',
#        'KV', 'SI', 'HR', 'MJ', 'BO', 'MT', 'EN', 'BK', 'CI', 'UY', 'AN',
#        'BH', 'BL', 'BA', 'PL', 'PA', 'CS', 'NP', 'ES', 'RQ', 'AY', 'MD',
#        'OS', 'AJ', 'DR', 'FI', 'AC', 'WI', 'MY', 'CB', 'BP', 'TV', 'PP',
#        'NH', 'FJ', 'FP', 'TT', 'KT', 'IM', 'LO', 'MN', 'TD', 'GG', 'SB',
#        'GI', 'TW', 'HO', 'BX', 'JM', 'GT', 'BD', 'NU', 'WE', 'TN', 'MH',
#        'BB', 'MV', 'LS', 'VT', 'GZ', 'MC', 'PG', 'RE', 'CW', 'GY', 'CN',
#        'CV', 'CJ', 'ST', 'LA', 'DO', 'VQ', 'FO', 'PS', 'GK', 'RN', 'GJ',
#        'FG', 'NC', 'MF', 'FM', 'YI', 'PC', 'RM', 'TK', 'GQ', 'OC', 'KR',
#        'SV', 'AQ', 'WS', 'VC', 'SM'], dtype=object)

# %% [markdown]
# ### Protests for rigths:

# %%
#Getting number of protests related to rights 
query_rights_protests = bigquery_client.query(
    """SELECT COUNT(EventCode) as nb_protests FROM `gdelt-bq.gdeltv2.events` 
    WHERE EventCode LIKE '1413' OR EventCode LIKE '1423' 
    OR EventCode LIKE '1433' OR EventCode LIKE '1443' OR EventCode LIKE '1453'""")
rights_protests_df = query_rights_protests.result().to_dataframe()

# %%
rights_protests_df.head()
# Out:
#    nb_protests
# 0          630

# %% [markdown]
# ### Country codes conversion iso2 to iso3 and iso3 to name:

# %%
#Getting conversion between iso2 and iso3 code for countries
country_codes_iso2_to_iso3 = pd.read_csv(DATA_PATH + "country_codes_iso2_to_iso3.csv", encoding = "ISO-8859-1")
country_codes_iso2_to_iso3.head()
# Out:
#   ISO ISO3
# 0  AD  AND
# 1  AE  ARE
# 2  AF  AFG
# 3  AG  ATG
# 4  AI  AIA

# %%
country_codes_fips104_to_iso = pd.read_csv(DATA_PATH + "fips104_to_iso.csv", encoding = "ISO-8859-1")
country_codes_fips104_to_iso.head()
# Out:
#   FIPS 10-4 ISO 3166            Name
# 0        AF       AF     Afghanistan
# 1        AX        -        Akrotiri
# 2        AL       AL         Albania
# 3        AG       DZ         Algeria
# 4        AQ       AS  American Samoa

# %%
country_codes_fips104_to_iso3 = pd.merge(country_codes_fips104_to_iso, country_codes_iso2_to_iso3, how='inner', left_on=['ISO 3166'], right_on=['ISO'])

# %%
country_codes_fips104_to_iso3[country_codes_fips104_to_iso3['FIPS 10-4']=='IC']
# Out:
#     FIPS 10-4 ISO 3166     Name ISO ISO3
# 124        IC       IS  Iceland  IS  ISL

# %%
#Getting conversion between country code and country name
country_codes_to_name = pd.read_csv(DATA_PATH + "country_code_to_name.csv", encoding = "ISO-8859-1")
country_codes_to_name.head()
# Out:
#   Country Code          Country Name
# 0          AND               Andorra
# 1          ARE  United Arab Emirates
# 2          AFG           Afghanistan
# 3          ATG   Antigua and Barbuda
# 4          AIA              Anguilla

# %% [markdown]
# ### Getting statistics on countries:

# %%
#Getting data about statistics on all the countries
countries_stats = pd.read_csv(DATA_PATH + "countries_stats.csv", encoding = "ISO-8859-1")
countries_stats.head()
# Out:
#      Country Name                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 2          -0.39                               31.00              6000.0
# 3         -20.71                                9.27              8000.0
# 4           6.60                                4.05             19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34        0.380     0.240    0.380
# 1      15.11       5.22        0.232     0.188    0.579
# 2      17.14       4.61        0.101     0.600    0.298
# 3      22.46       3.27          NaN       NaN      NaN
# 4       8.71       6.25          NaN       NaN      NaN

# %% [markdown]
# ### Visualizing average income per country on a world map

# %%
countries_topodata = json.load(open('data/contries.topojson.json'))

# %%
# world_map = folium.Map([20,0], tiles='cartodbpositron', zoom_start=1)
# folium.GeoJson(geo_json_data).add_to(world_map)

# world_map.save('world_map.html')
# display(HTML("<h1><a href='world_map.html' target='_blank'>world_map (Ctrl+Click)</a></h1>"))

# world_map

# %%
world_map = folium.Map([46.75,8.25],  zoom_start=1, tiles='cartodbpositron') #creating a map


#adding the boundaries of the cantons and highlight them in red
folium.TopoJson(countries_topodata,'objects.countries1', style_function=lambda feature: {
        'fillColor':'red',
        'fillOpacity': '0.1',
        'color' : 'red',
        'line_opacity':'1',
        'weight' : 1,
        },
        tooltip=folium.GeoJsonTooltip(fields=['name'],
                                  aliases=[''], 
                                  sticky=True, 
                                  style="font-family: Arial; color: black;", 
                                  opacity=0.8, 
                                  direction='top')
).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Displaying the income in 2017
country_by_income_2017 = country_by_income_per_year[country_by_income_per_year['Year'] == 2017]
country_by_income_2017.head()
# Out:
#      Country Code                Economy  Income Group  Year Latitude  \
# 6540          ZWE               Zimbabwe             1  2017  -19,098
# 6541          ZMB                 Zambia             3  2017   -15,13
# 6542          YEM            Yemen, Rep.             1  2017   15,569
# 6543          PSE     West Bank and Gaza             3  2017   32,097
# 6544          VIR  Virgin Islands (U.S.)             6  2017    17,74
#
#      Longitude
# 6540    30,047
# 6541    25,268
# 6542    47,793
# 6543     35,26
# 6544     -64,8

# %%
colormap = linear.YlGn_09.scale(1, 6)
colormap.caption = 'Income per cap in 2017 (Low = 1, High = 6)'
swiss_loc=[46.9,8.25]
results_map_income = folium.Map(swiss_loc, tiles='cartodbpositron', zoom_start=1) 
#creating dictionary to easily find the UDC voting rate
dictionary = country_by_income_2017.set_index('Country Code')['Income Group']#clean_data.set_index('CantonID')['UDC']
#Our own choropleth 
folium.TopoJson(
    countries_topodata,
#     open('data/contries.topojson.json'),
    'objects.countries1',
    style_function=lambda x: {
        'fillColor': '#black' if (x['id'] not in dictionary.index.values) or (pd.isnull(dictionary[x['id']])) else colormap(dictionary[x['id']]),
        'color': 'black',
        'weight': 0.5,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    },
    tooltip=folium.GeoJsonTooltip(fields=['name'],
                                  aliases=[''], 
                                  sticky=True, 
                                  style="font-family: Arial; color: black;", 
                                  opacity=0.8, 
                                  direction='top')
).add_to(results_map_income)
results_map_income.add_child(colormap) #adding legend to map


results_map_income.save('results_map_income.html')
display(HTML("<h1><a href='results_map_income.html' target='_blank'>results_map_income (Ctrl+Click)</a></h1>"))

results_map_income
# Out:
# <h1><a href='results_map_income.html' target='_blank'>results_map_income (Ctrl+Click)</a></h1>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# a=countries_topodata['objects']['countries1']['geometries']

# %%
# b = list(filter(lambda x: x['id'] in dictionary.index.values, a))

# %%
# countries_topodata['objects']['countries1']['geometries'] = b

# %%
# dictionary.index.values

# %%
# countries_topodata['objects']['countries1']

# %%
# a

# %%
# country_by_income_2017[country_by_income_2017['Country Code']=='XKX']

# %%
# world_map2 = folium.Map([20,0], tiles='cartodbpositron', zoom_start=1)
# # cantons_topodata = json.load(open('data/world-countries.topojson.json'))
# countries_topodata = json.load(open('data/contries.topojson.json'))
# folium.TopoJson(countries_topodata,
# #     'objects.world-countries',
#                 'objects.countries1',
#     name='topojson'
# ).add_to(world_map2)
# # fl.LayerControl().add_to(m_switz)
# # folium.TopoJson(
# #     cantons_topodata,
# #     'objects.world-countries',
# #     style_function=lambda x: {
# #         'fillOpacity': 1,
# #         'weight': 0,
# #         'fillColor': '#black'
# #     }#style_function
# # ).add_to(world_map2)
# world_map2

# %%
#Displaying the income in 2017
# country_by_income_2017 = country_by_income_per_year[country_by_income_per_year['Year'] == 2017]
# country_by_income_2017.head()

# %%
# results_map_income = folium.Map([20,0], tiles='cartodbpositron', zoom_start=2)
# folium.TopoJson(
#     countries_topodata,
#     'objects.countries1',
#     style_function=lambda x: {
#         'fillOpacity': 1,
#         'weight': 0,
#         'fillColor': '#black'
#     }#style_function
# ).add_to(results_map_income)
# results_map_income.choropleth(geo_data=geo_json_data, data=country_by_income_2017,
#              columns=['Country Code', 'Income Group' ],
#              key_on='feature.id',
#              fill_color='BuGn', fill_opacity=0.9, line_opacity=0.2,
#              legend_name='Income per cap in 2017 (Low = 1, High = 6)',
#                        reset=True)

# results_map_income.save('results_map_income.html')
# display(HTML("<h1><a href='results_map_income.html' target='_blank'>results_map_income (Ctrl+Click)</a></h1>"))

# results_map_income

# %% [markdown]
# Here, thanks to our visualization, we can estimate in which country the inhabitants have a better standard of living.

# %% [markdown]
# ### Displaying percentage of protests on a world map

# %%
protests_df.head()
# Out:
#        ActionGeo_CountryCode Actor1CountryCode  Actor1Geo_Lat  Actor1Geo_Long  \
# 410722                    SP               ABW        40.0000        -4.00000
# 410723                    NL               ABW        52.5000         5.75000
# 410724                    AA               ABW        52.5000         5.75000
# 410725                    NL               ABW        12.1667       -69.00000
# 410726                    MO               ABW        33.3139        -3.45309
#
#          AvgTone
# 410722 -1.449275
# 410723 -6.976744
# 410724 -6.976744
# 410725 -3.140097
# 410726  0.258398

# %%
country_codes_fips104_to_iso3.head()
# Out:
#   FIPS 10-4 ISO 3166            Name ISO ISO3
# 0        AF       AF     Afghanistan  AF  AFG
# 1        AL       AL         Albania  AL  ALB
# 2        AG       DZ         Algeria  DZ  DZA
# 3        AQ       AS  American Samoa  AS  ASM
# 4        AN       AD         Andorra  AD  AND

# %%
#join the protests dataframe to get the iso3 convention for each country
# protests_df=pd.merge(protests_df, country_codes_iso2_to_iso3, how='right', left_on=['ActionGeo_CountryCode'], right_on=['ISO'])
# protests_df2 = protests_df['Actor1CountryCode'].copy()
# protests_df=pd.merge(protests_df, country_codes_iso2_to_iso3, how='right', left_on=['ActionGeo_CountryCode'], right_on=['ISO'])
protests_df=pd.merge(protests_df, country_codes_fips104_to_iso3, how='right', left_on=['ActionGeo_CountryCode'], right_on=['FIPS 10-4'])

# %%
protests_df2.head()#['ISO3'].unique()
# Out:
#   ActionGeo_CountryCode Actor1CountryCode  Actor1Geo_Lat  Actor1Geo_Long  \
# 0                    SP               ABW        40.0000         -4.0000
# 1                    SP               AFG        40.0000         -4.0000
# 2                    SP               AFG        31.5938         64.3716
# 3                    SP               AFR        40.0000         -4.0000
# 4                    SP               AFR        40.0000         -4.0000
#
#     AvgTone FIPS 10-4 ISO 3166   Name ISO ISO3
# 0 -1.449275        SP       ES  Spain  ES  ESP
# 1 -4.641350        SP       ES  Spain  ES  ESP
# 2 -4.641350        SP       ES  Spain  ES  ESP
# 3 -8.390023        SP       ES  Spain  ES  ESP
# 4 -0.418994        SP       ES  Spain  ES  ESP

# %%
protests_df2[protests_df2['ISO3']=='ISL']
# Out:
#        ActionGeo_CountryCode Actor1CountryCode  Actor1Geo_Lat  Actor1Geo_Long  \
# 214829                    IC               AFG        33.0000         65.0000
# 214830                    IC               AFG        33.0000         65.0000
# 214831                    IC               AFG        33.0000         65.0000
# 214832                    IC               ARG        65.0000        -18.0000
# 214833                    IC               ARG        65.0000        -18.0000
# 214834                    IC               AUT        64.1500        -21.9500
# 214835                    IC               DNK        64.1500        -21.9500
# 214836                    IC               EGY        65.0000        -18.0000
# 214837                    IC               ESP        65.2667        -20.0000
# 214838                    IC               EUR        65.0000        -18.0000
# 214839                    IC               EUR        65.0000        -18.0000
# 214840                    IC               EUR        65.0000        -18.0000
# 214841                    IC               EUR        65.0000        -18.0000
# 214842                    IC               EUR        65.0000        -18.0000
# 214843                    IC               EUR        52.2500         21.0000
# 214844                    IC               EUR        64.3167        -20.3000
# 214845                    IC               FRA        65.0000        -18.0000
# 214846                    IC               FRA        65.0000        -18.0000
# 214847                    IC               FRA        65.0000        -18.0000
# 214848                    IC               FRA        65.0000        -18.0000
# 214849                    IC               FRA        64.1500        -21.9500
# 214850                    IC               FRA        64.1500        -21.9500
# 214851                    IC               FRA        64.1500        -21.9500
# 214852                    IC               FRA        25.6667       -100.3170
# 214853                    IC               GBR        54.0000         -2.0000
# 214854                    IC               GBR        65.0000        -18.0000
# 214855                    IC               GBR        65.0000        -18.0000
# 214856                    IC               GBR        65.0000        -18.0000
# 214857                    IC               GBR        64.0000         26.0000
# 214858                    IC               IDN        65.0000        -18.0000
# ...                      ...               ...            ...             ...
# 215022                    IC               ISL        65.6829        -18.0914
# 215023                    IC               ISL        65.0416        -16.8022
# 215024                    IC               ISR        31.5000         34.7500
# 215025                    IC               ISR        31.5000         34.7500
# 215026                    IC               ISR        31.5000         34.7500
# 215027                    IC               NGA        65.0000        -18.0000
# 215028                    IC               NGA        65.0000        -18.0000
# 215029                    IC               NGA        65.0000        -18.0000
# 215030                    IC               NOR        65.0000        -18.0000
# 215031                    IC               PAK        31.5497         74.3436
# 215032                    IC               PAN         9.0000        -80.0000
# 215033                    IC               PAN         9.0000        -80.0000
# 215034                    IC               PAN         9.0000        -80.0000
# 215035                    IC               PAN         9.0000        -80.0000
# 215036                    IC               PAN        64.1500        -21.9500
# 215037                    IC               POL        65.0000        -18.0000
# 215038                    IC               POL        52.2500         21.0000
# 215039                    IC               PRT        65.0000        -18.0000
# 215040                    IC               SWE        64.1500        -21.9500
# 215041                    IC               SYR        65.0000        -18.0000
# 215042                    IC               TUR        65.0000        -18.0000
# 215043                    IC               USA        65.0000        -18.0000
# 215044                    IC               USA        65.0000        -18.0000
# 215045                    IC               USA        65.0000        -18.0000
# 215046                    IC               USA        65.0000        -18.0000
# 215047                    IC               USA        65.0000        -18.0000
# 215048                    IC               USA        65.0000        -18.0000
# 215049                    IC               USA        65.0000        -18.0000
# 215050                    IC               USA        65.0000        -18.0000
# 215051                    IC               USA        64.1500        -21.9500
#
#          AvgTone FIPS 10-4 ISO 3166     Name ISO ISO3
# 214829 -2.570694        IC       IS  Iceland  IS  ISL
# 214830 -2.570694        IC       IS  Iceland  IS  ISL
# 214831 -2.570694        IC       IS  Iceland  IS  ISL
# 214832 -6.321839        IC       IS  Iceland  IS  ISL
# 214833 -5.820106        IC       IS  Iceland  IS  ISL
# 214834 -2.188184        IC       IS  Iceland  IS  ISL
# 214835  2.702703        IC       IS  Iceland  IS  ISL
# 214836 -1.574803        IC       IS  Iceland  IS  ISL
# 214837 -2.833530        IC       IS  Iceland  IS  ISL
# 214838 -4.705882        IC       IS  Iceland  IS  ISL
# 214839 -3.910210        IC       IS  Iceland  IS  ISL
# 214840  0.687285        IC       IS  Iceland  IS  ISL
# 214841 -7.258609        IC       IS  Iceland  IS  ISL
# 214842 -4.009870        IC       IS  Iceland  IS  ISL
# 214843 -7.258609        IC       IS  Iceland  IS  ISL
# 214844 -0.353357        IC       IS  Iceland  IS  ISL
# 214845  1.809955        IC       IS  Iceland  IS  ISL
# 214846 -1.421801        IC       IS  Iceland  IS  ISL
# 214847  1.092896        IC       IS  Iceland  IS  ISL
# 214848  0.490196        IC       IS  Iceland  IS  ISL
# 214849  1.315789        IC       IS  Iceland  IS  ISL
# 214850 -1.701323        IC       IS  Iceland  IS  ISL
# 214851 -3.069054        IC       IS  Iceland  IS  ISL
# 214852 -0.719424        IC       IS  Iceland  IS  ISL
# 214853  0.000000        IC       IS  Iceland  IS  ISL
# 214854 -1.734104        IC       IS  Iceland  IS  ISL
# 214855 -1.188017        IC       IS  Iceland  IS  ISL
# 214856 -1.188017        IC       IS  Iceland  IS  ISL
# 214857  0.000000        IC       IS  Iceland  IS  ISL
# 214858  2.995720        IC       IS  Iceland  IS  ISL
# ...          ...       ...      ...      ...  ..  ...
# 215022 -8.988764        IC       IS  Iceland  IS  ISL
# 215023 -1.092150        IC       IS  Iceland  IS  ISL
# 215024 -3.571429        IC       IS  Iceland  IS  ISL
# 215025 -3.571429        IC       IS  Iceland  IS  ISL
# 215026 -1.204819        IC       IS  Iceland  IS  ISL
# 215027 -0.667302        IC       IS  Iceland  IS  ISL
# 215028 -0.787084        IC       IS  Iceland  IS  ISL
# 215029 -0.373134        IC       IS  Iceland  IS  ISL
# 215030  0.000000        IC       IS  Iceland  IS  ISL
# 215031 -6.083650        IC       IS  Iceland  IS  ISL
# 215032 -4.911092        IC       IS  Iceland  IS  ISL
# 215033 -5.458515        IC       IS  Iceland  IS  ISL
# 215034 -4.911092        IC       IS  Iceland  IS  ISL
# 215035 -6.986900        IC       IS  Iceland  IS  ISL
# 215036 -6.185567        IC       IS  Iceland  IS  ISL
# 215037 -7.984575        IC       IS  Iceland  IS  ISL
# 215038 -5.683837        IC       IS  Iceland  IS  ISL
# 215039 -3.768116        IC       IS  Iceland  IS  ISL
# 215040 -0.479616        IC       IS  Iceland  IS  ISL
# 215041 -9.500000        IC       IS  Iceland  IS  ISL
# 215042 -3.211009        IC       IS  Iceland  IS  ISL
# 215043 -1.609719        IC       IS  Iceland  IS  ISL
# 215044 -1.478689        IC       IS  Iceland  IS  ISL
# 215045 -4.810997        IC       IS  Iceland  IS  ISL
# 215046 -4.810997        IC       IS  Iceland  IS  ISL
# 215047 -5.931034        IC       IS  Iceland  IS  ISL
# 215048 -0.496278        IC       IS  Iceland  IS  ISL
# 215049 -4.385965        IC       IS  Iceland  IS  ISL
# 215050 -4.363636        IC       IS  Iceland  IS  ISL
# 215051 -3.087479        IC       IS  Iceland  IS  ISL
#
# [223 rows x 10 columns]

# %%
country_codes_iso2_to_iso3['ISO3'].unique()
# Out:
# array(['AND', 'ARE', 'AFG', 'ATG', 'AIA', 'ALB', 'ARM', 'AGO', 'ATA',
#        'ARG', 'ASM', 'AUT', 'AUS', 'ABW', 'ALA', 'AZE', 'BIH', 'BRB',
#        'BGD', 'BEL', 'BFA', 'BGR', 'BHR', 'BDI', 'BEN', 'BLM', 'BMU',
#        'BRN', 'BOL', 'BES', 'BRA', 'BHS', 'BTN', 'BVT', 'BWA', 'BLR',
#        'BLZ', 'CAN', 'CCK', 'COD', 'CAF', 'COG', 'CHE', 'CIV', 'COK',
#        'CHL', 'CMR', 'CHN', 'COL', 'CRI', 'CUB', 'CPV', 'CUW', 'CXR',
#        'CYP', 'CZE', 'DEU', 'DJI', 'DNK', 'DMA', 'DOM', 'DZA', 'ECU',
#        'EST', 'EGY', 'ESH', 'ERI', 'ESP', 'ETH', 'FIN', 'FJI', 'FLK',
#        'FSM', 'FRO', 'FRA', 'GAB', 'GBR', 'GRD', 'GEO', 'GUF', 'GGY',
#        'GHA', 'GIB', 'GRL', 'GMB', 'GIN', 'GLP', 'GNQ', 'GRC', 'SGS',
#        'GTM', 'GUM', 'GNB', 'GUY', 'HKG', 'HMD', 'HND', 'HRV', 'HTI',
#        'HUN', 'IDN', 'IRL', 'ISR', 'IMN', 'IND', 'IOT', 'IRQ', 'IRN',
#        'ISL', 'ITA', 'JEY', 'JAM', 'JOR', 'JPN', 'KEN', 'KGZ', 'KHM',
#        'KIR', 'COM', 'KNA', 'PRK', 'KOR', 'XKX', 'KWT', 'CYM', 'KAZ',
#        'LAO', 'LBN', 'LCA', 'LIE', 'LKA', 'LBR', 'LSO', 'LTU', 'LUX',
#        'LVA', 'LBY', 'MAR', 'MCO', 'MDA', 'MNE', 'MAF', 'MDG', 'MHL',
#        'MKD', 'MLI', 'MMR', 'MNG', 'MAC', 'MNP', 'MTQ', 'MRT', 'MSR',
#        'MLT', 'MUS', 'MDV', 'MWI', 'MEX', 'MYS', 'MOZ', 'NAM', 'NCL',
#        'NER', 'NFK', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NRU', 'NIU',
#        'NZL', 'OMN', 'PAN', 'PER', 'PYF', 'PNG', 'PHL', 'PAK', 'POL',
#        'SPM', 'PCN', 'PRI', 'PSE', 'PRT', 'PLW', 'PRY', 'QAT', 'REU',
#        'ROU', 'SRB', 'RUS', 'RWA', 'SAU', 'SLB', 'SYC', 'SDN', 'SSD',
#        'SWE', 'SGP', 'SHN', 'SVN', 'SJM', 'SVK', 'SLE', 'SMR', 'SEN',
#        'SOM', 'SUR', 'STP', 'SLV', 'SXM', 'SYR', 'SWZ', 'TCA', 'TCD',
#        'ATF', 'TGO', 'THA', 'TJK', 'TKL', 'TLS', 'TKM', 'TUN', 'TON',
#        'TUR', 'TTO', 'TUV', 'TWN', 'TZA', 'UKR', 'UGA', 'UMI', 'USA',
#        'URY', 'UZB', 'VAT', 'VCT', 'VEN', 'VGB', 'VIR', 'VNM', 'VUT',
#        'WLF', 'WSM', 'YEM', 'MYT', 'ZAF', 'ZMB', 'ZWE', 'SCG', 'ANT'],
#       dtype=object)

# %%
country_codes_iso2_to_iso3['ISO'].unique()
# Out:
# array(['AD', 'AE', 'AF', 'AG', 'AI', 'AL', 'AM', 'AO', 'AQ', 'AR', 'AS',
#        'AT', 'AU', 'AW', 'AX', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG',
#        'BH', 'BI', 'BJ', 'BL', 'BM', 'BN', 'BO', 'BQ', 'BR', 'BS', 'BT',
#        'BV', 'BW', 'BY', 'BZ', 'CA', 'CC', 'CD', 'CF', 'CG', 'CH', 'CI',
#        'CK', 'CL', 'CM', 'CN', 'CO', 'CR', 'CU', 'CV', 'CW', 'CX', 'CY',
#        'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'EH',
#        'ER', 'ES', 'ET', 'FI', 'FJ', 'FK', 'FM', 'FO', 'FR', 'GA', 'GB',
#        'GD', 'GE', 'GF', 'GG', 'GH', 'GI', 'GL', 'GM', 'GN', 'GP', 'GQ',
#        'GR', 'GS', 'GT', 'GU', 'GW', 'GY', 'HK', 'HM', 'HN', 'HR', 'HT',
#        'HU', 'ID', 'IE', 'IL', 'IM', 'IN', 'IO', 'IQ', 'IR', 'IS', 'IT',
#        'JE', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KP',
#        'KR', 'XK', 'KW', 'KY', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR',
#        'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MF', 'MG',
#        'MH', 'MK', 'ML', 'MM', 'MN', 'MO', 'MP', 'MQ', 'MR', 'MS', 'MT',
#        'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', nan, 'NC', 'NE', 'NF', 'NG',
#        'NI', 'NL', 'NO', 'NP', 'NR', 'NU', 'NZ', 'OM', 'PA', 'PE', 'PF',
#        'PG', 'PH', 'PK', 'PL', 'PM', 'PN', 'PR', 'PS', 'PT', 'PW', 'PY',
#        'QA', 'RE', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SD', 'SS',
#        'SE', 'SG', 'SH', 'SI', 'SJ', 'SK', 'SL', 'SM', 'SN', 'SO', 'SR',
#        'ST', 'SV', 'SX', 'SY', 'SZ', 'TC', 'TD', 'TF', 'TG', 'TH', 'TJ',
#        'TK', 'TL', 'TM', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA',
#        'UG', 'UM', 'US', 'UY', 'UZ', 'VA', 'VC', 'VE', 'VG', 'VI', 'VN',
#        'VU', 'WF', 'WS', 'YE', 'YT', 'ZA', 'ZM', 'ZW', 'CS', 'AN'],
#       dtype=object)

# %%
protests_df.head()
# Out:
#   ActionGeo_CountryCode Actor1CountryCode  Actor1Geo_Lat  Actor1Geo_Long  \
# 0                    SP               ABW        40.0000         -4.0000
# 1                    SP               AFG        40.0000         -4.0000
# 2                    SP               AFG        31.5938         64.3716
# 3                    SP               AFR        40.0000         -4.0000
# 4                    SP               AFR        40.0000         -4.0000
#
#     AvgTone FIPS 10-4 ISO 3166   Name ISO ISO3
# 0 -1.449275        SP       ES  Spain  ES  ESP
# 1 -4.641350        SP       ES  Spain  ES  ESP
# 2 -4.641350        SP       ES  Spain  ES  ESP
# 3 -8.390023        SP       ES  Spain  ES  ESP
# 4 -0.418994        SP       ES  Spain  ES  ESP

# %%
number_of_protests_per_country[number_of_protests_per_country['ISO3']=='ISL']
# Out:
#     ISO3  protests count
# 105  ISL             223

# %%
#changing the column name to keep the same naming convention in each dataframe
# protests_df=protests_df.rename(index=str, columns={"ISO3": "Country Code"})

#counting the number of protests we have in each country
number_of_protests_per_country = protests_df.groupby(['ISO3']).size().reset_index(name='protests count')

#Getting the distribution of protests count
plt.hist(number_of_protests_per_country['protests count'], color = 'blue', edgecolor = 'black',
         bins = int(180/5))

# Add labels
plt.title('Histogram of protests count')
plt.xlabel('Protests count')
plt.ylabel('Countries number')
# Out:
# Text(0, 0.5, 'Countries number')

# %% [markdown]
# The distribution show that few countries have a very high number of protests. These countries, with a very high number, hids the nuance between other countries.
#
# For instance, if a country A has 1 protests, a country B has 5000 protests and country C has 100 000 protests, we won't see any difference between country A and B in the visualization. A threshold resolves this issue.
#
# To resolve this issue we thought about two different solutions:
# - adding a threshold: but we loose nuance between countries with higher number of protests
# - doing a log scale

# %% [markdown]
# ##### Threshold:

# %%
# threshold = 7000
# number_of_protests_per_country[number_of_protests_per_country['protests count'] > threshold] = threshold

# #Getting the new distribution of protests count after the threshold
# plt.hist(number_of_protests_per_country['protests count'], color = 'blue', edgecolor = 'black',
#          bins = int(180/5))

# # Add labels
# plt.title('Histogram of protests count')
# plt.xlabel('Protests count')
# plt.ylabel('Countries number')

# %% [markdown]
# #### Log scale:

# %%
number_of_protests_per_country['log protests count'] = np.log10(number_of_protests_per_country['protests count'])
#Getting the distribution of logarithmic protests count
plt.hist(number_of_protests_per_country['log protests count'], color = 'blue', edgecolor = 'black',
         bins = int(180/5))

# Add labels
plt.title('Histogram of protests count')
plt.xlabel('Protests count')
plt.ylabel('Countries number')
# Out:
# Text(0, 0.5, 'Countries number')

# %% [markdown]
# Visualizing result for log scale that allows to avoid loosing nuance between low values and between high values:

# %%
number_of_protests_per_country.head()
# Out:
#   ISO3  protests count  log protests count
# 0  ABW              14            1.146128
# 1  AFG            1813            3.258398
# 2  AGO             519            2.715167
# 3  AIA               1            0.000000
# 4  ALB            1227            3.088845

# %%
results_map_protests = folium.Map([20,0], tiles='cartodbpositron', zoom_start=2)
results_map_protests.choropleth(geo_data=geo_json_data, data=number_of_protests_per_country,
             columns=['Country Code', 'log protests count'],
             key_on='feature.id',
             fill_color='YlGnBu', fill_opacity=0.9, line_opacity=0.2,
             legend_name='Number of protests from 2005 (log scale)',
                       reset=True)

results_map_protests.save('results_map_protests.html')
display(HTML("<h1><a href='results_map_protests.html' target='_blank'>results_map_protests (Ctrl+Click)</a></h1>"))

results_map_protests
# Out:
# <h1><a href='results_map_protests.html' target='_blank'>results_map_protests (Ctrl+Click)</a></h1>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
number_of_protests_per_country[number_of_protests_per_country['Country Code'] =='FRA']
# Out:
# Empty DataFrame
# Columns: [Country Code, protests count, log protests count]
# Index: []

# %%
np.log(dictionary.values)#['protests count']
# Out:
# array([0.        , 8.17188201, 6.74641213, 0.        , 0.        ,
#        8.01862547, 0.        , 4.09434456, 6.98933527, 8.05832731,
#        8.03527891, 8.5943394 , 1.09861229, 0.        , 7.72134861,
#        7.28619171, 0.        , 0.        , 0.        , 7.93951526,
#        0.        , 0.        , 5.17614973, 4.2341065 , 8.85366543,
#        4.78749174, 0.        , 7.23705903, 7.53689713, 6.98564182,
#        0.        , 6.89264164, 7.40671073, 8.71308887, 4.15888308,
#        6.23441073, 4.39444915, 0.        , 0.        , 6.99484999,
#        8.77012853, 0.        , 8.85366543, 0.        , 3.21887582,
#        7.83952558, 6.56667243, 5.64190707, 6.58479139, 0.        ,
#        7.971431  , 0.        , 2.77258872, 0.        , 7.95962531,
#        2.30258509, 0.        , 0.        , 6.51174533, 0.        ,
#        0.        , 5.48063892, 0.        , 0.        , 4.54329478,
#        0.        , 6.69950034, 8.85366543, 5.08759634, 0.        ,
#        5.90263333, 0.        , 7.40671073, 6.65027905, 4.8978398 ,
#        0.        , 8.85366543, 1.79175947, 0.69314718, 5.93753621,
#        6.06610809, 0.        , 6.19236249, 7.41095188, 4.24849524,
#        0.        , 5.80211838, 8.85366543, 0.        , 4.24849524,
#        8.85366543, 0.        , 3.36729583, 7.30249642, 0.        ,
#        0.        , 5.32787617, 6.57925121, 0.        , 0.        ,
#        7.24779258, 0.        , 7.35308192, 8.43119948, 0.69314718,
#        8.85366543, 0.        , 0.        , 8.85366543, 0.        ,
#        8.85366543, 0.        , 8.85366543, 5.44241771, 5.86363118,
#        7.6453977 , 0.        , 6.57646957, 8.38753998, 6.23441073,
#        0.        , 0.        , 7.29301768, 1.79175947, 0.        ,
#        3.93182563, 0.        , 0.        , 7.98650494, 0.        ,
#        6.12029742, 0.        , 2.39789527, 4.24849524, 5.52942909,
#        0.        , 8.13505391, 2.7080502 , 5.22035583, 2.94443898,
#        7.34471905, 5.31811999, 5.04985601, 8.85366543, 3.58351894,
#        8.07121854, 7.1808312 , 5.98141421, 0.        , 0.        ,
#        3.8501476 , 6.1717006 , 5.84064166, 6.44730586, 0.        ,
#        0.        , 6.26339826, 0.        , 7.48829352, 0.        ,
#        0.        , 2.99573227, 0.        , 0.        , 6.37161185,
#        8.85366543, 7.44833386, 7.96728018, 7.0440329 , 7.84698098,
#        4.84418709, 6.96129605, 0.        , 8.85366543, 6.27098843,
#        0.        , 7.69802917, 0.        , 0.        , 0.        ,
#        8.2171686 , 0.        , 0.        , 0.        , 0.        ,
#        4.58496748, 0.        , 6.96508035, 4.66343909, 8.37470754,
#        0.        , 6.26530121, 8.70101362, 5.33271879, 0.        ,
#        6.57646957, 6.59578051, 0.        , 0.        , 0.        ,
#        0.        , 5.34710753, 1.79175947, 1.79175947, 7.36201055,
#        6.95749737, 8.85366543, 0.        , 2.89037176, 0.        ,
#        0.        , 5.65948222, 3.71357207, 8.13358742, 0.        ,
#        0.        , 8.85366543, 0.        , 5.68697536, 0.        ,
#        6.94119006, 0.        , 3.91202301, 0.        , 0.        ,
#        6.17794411, 3.80666249, 3.33220451, 0.        , 2.07944154,
#        6.54965074, 6.92657703, 7.10906214, 0.        , 0.        ,
#        6.92165818, 8.85366543, 5.27299956, 0.        , 3.61091791,
#        8.85366543, 0.        , 4.15888308, 0.        , 0.        ,
#        0.        , 3.95124372, 0.        , 0.        , 6.3952616 ,
#        0.        , 0.        ])

# %%
country_by_income_2017[country_by_income_2017['Economy']=='Roumania']
# Out:
# Empty DataFrame
# Columns: [Country Code, Economy, Income Group, Year, Latitude, Longitude]
# Index: []

# %%
number_of_protests_per_country['Country Code'].values
# Out:
# array(['ABW', 'AFG', 'AFR', 'AGO', 'AIA', 'ALB', 'AND', 'ARE', 'ARG',
#        'ARM', 'ASA', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN',
#        'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BLR', 'BLZ', 'BMU', 'BOL',
#        'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COK', 'COL', 'COM', 'CPV',
#        'CRB', 'CRI', 'CUB', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA',
#        'DNK', 'DOM', 'DZA', 'EAF', 'ECU', 'EGY', 'ERI', 'ESP', 'EST',
#        'ETH', 'EUR', 'FIN', 'FJI', 'FRA', 'FSM', 'GAB', 'GBR', 'GEO',
#        'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GTM', 'GUY',
#        'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IND', 'IRL', 'IRN',
#        'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN',
#        'KGZ', 'KHM', 'KNA', 'KOR', 'KWT', 'LAM', 'LAO', 'LBN', 'LBR',
#        'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAR',
#        'MCO', 'MDA', 'MDG', 'MDV', 'MEA', 'MEX', 'MHL', 'MKD', 'MLI',
#        'MLT', 'MMR', 'MNG', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', 'NAM',
#        'NER', 'NGA', 'NIC', 'NLD', 'NMR', 'NOR', 'NPL', 'NRU', 'NZL',
#        'OMN', 'PAK', 'PAN', 'PER', 'PGS', 'PHL', 'PLW', 'PNG', 'POL',
#        'PRK', 'PRT', 'PRY', 'PSE', 'QAT', 'ROM', 'RUS', 'RWA', 'SAF',
#        'SAS', 'SAU', 'SDN', 'SEA', 'SEN', 'SGP', 'SHN', 'SLB', 'SLE',
#        'SLV', 'SMR', 'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SWE',
#        'SWZ', 'SYC', 'SYR', 'TCD', 'TGO', 'THA', 'TJK', 'TKM', 'TMP',
#        'TON', 'TTO', 'TUN', 'TUR', 'TWN', 'TZA', 'UGA', 'UKR', 'URY',
#        'USA', 'UZB', 'VAT', 'VCT', 'VEN', 'VNM', 'VUT', 'WAF', 'WLF',
#        'WSM', 'WST', 'YEM', 'ZAF', 'ZMB', 'ZWE'], dtype=object)

# %%
country_by_income_2017['Country Code'].values
# Out:
# array(['ZWE', 'ZMB', 'YEM', 'PSE', 'VIR', 'VNM', 'VEN', 'VUT', 'UZB',
#        'URY', 'USA', 'GBR', 'ARE', 'UKR', 'UGA', 'TUV', 'TCA', 'TKM',
#        'TUR', 'TUN', 'TTO', 'TON', 'TGO', 'TLS', 'THA', 'TZA', 'TJK',
#        'TWN', 'SYR', 'CHE', 'SWE', 'SWZ', 'SUR', 'SDN', 'VCT', 'MAF',
#        'LCA', 'KNA', 'LKA', 'ESP', 'SSD', 'ZAF', 'SOM', 'SLB', 'SVN',
#        'SVK', 'SXM', 'SGP', 'SLE', 'SYC', 'SRB', 'SEN', 'SAU', 'STP',
#        'SMR', 'WSM', 'RWA', 'RUS', 'ROU', 'QAT', 'PRI', 'PRT', 'POL',
#        'PHL', 'PER', 'PRY', 'PNG', 'PAN', 'PLW', 'PAK', 'OMN', 'NOR',
#        'MNP', 'NGA', 'NER', 'NIC', 'NZL', 'NCL', 'NLD', 'NPL', 'NRU',
#        'NAM', 'MMR', 'MOZ', 'MAR', 'MNE', 'MNG', 'MCO', 'MDA', 'FSM',
#        'MEX', 'MUS', 'MRT', 'MHL', 'MLT', 'MLI', 'MDV', 'MYS', 'MWI',
#        'MDG', 'MKD', 'MAC', 'LUX', 'LTU', 'LIE', 'LBY', 'LBR', 'LSO',
#        'LBN', 'LVA', 'LAO', 'KGZ', 'KWT', 'XKX', 'KOR', 'PRK', 'KIR',
#        'KEN', 'KAZ', 'JOR', 'JPN', 'JAM', 'ITA', 'ISR', 'IMN', 'IRL',
#        'IRQ', 'IRN', 'IDN', 'IND', 'ISL', 'HUN', 'HKG', 'HND', 'HTI',
#        'GUY', 'GNB', 'GIN', 'GTM', 'GUM', 'GRD', 'GRL', 'GRC', 'GIB',
#        'GHA', 'DEU', 'GEO', 'GMB', 'GAB', 'PYF', 'FRA', 'FIN', 'FJI',
#        'FRO', 'ETH', 'EST', 'ERI', 'GNQ', 'SLV', 'EGY', 'ECU', 'DOM',
#        'DMA', 'DJI', 'DNK', 'CZE', 'CYP', 'CUW', 'CUB', 'HRV', 'CIV',
#        'CRI', 'COG', 'COD', 'COM', 'COL', 'CHN', 'CHL', 'CHI', 'TCD',
#        'CAF', 'CYM', 'CAN', 'CMR', 'KHM', 'CPV', 'BDI', 'BFA', 'BGR',
#        'BRN', 'VGB', 'BRA', 'BWA', 'BIH', 'BOL', 'BTN', 'BMU', 'BEN',
#        'BLZ', 'BEL', 'BLR', 'BRB', 'BGD', 'BHR', 'BHS', 'AZE', 'AUT',
#        'AUS', 'ABW', 'ARM', 'ARG', 'ATG', 'AGO', 'AND', 'ASM', 'DZA',
#        'ALB', 'AFG'], dtype=object)

# %%
number_of_protests_per_country.columns=['Country Code', 'protests count', 'log protests count']
number_of_protests_per_country.head()
# Out:
#   Country Code  protests count  log protests count
# 0          ABW              14            1.146128
# 1          AFG            1813            3.258398
# 2          AGO             519            2.715167
# 3          AIA               1            0.000000
# 4          ALB            1227            3.088845

# %%
number_of_protests_per_country['protests count'].values.max()
# Out:
# 53411

# %%
colormap = linear.YlGn_09.scale(1, 5)
colormap.caption = 'Number of protests from 2005 (log scale)'
swiss_loc=[46.9,8.25]
results_map_protests = folium.Map(swiss_loc, tiles='cartodbpositron', zoom_start=1) 
#creating dictionary to easily find the UDC voting rate
dictionary = number_of_protests_per_country.set_index('Country Code')['log protests count']
# dictionary['protests count'] = np.log10(number_of_protests_per_country['protests count'].values)

#number_of_protests_per_country.set_index('Country Code')['protests count']#clean_data.set_index('CantonID')['UDC']

# dictionary.values = np.log(dictionary.values)
#Our own choropleth 
folium.TopoJson(
    countries_topodata,
#     open('data/contries.topojson.json'),
    'objects.countries1',
    style_function=lambda x: {
        'fillColor': '#black' if (x['id'] not in dictionary.index.values) or (pd.isnull(dictionary[x['id']])) else (colormap(dictionary[x['id']])),
        'color': 'black',
        'weight': 0.5,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    },
    tooltip=folium.GeoJsonTooltip(fields=['name'],
                                  aliases=[''], 
                                  sticky=True, 
                                  style="font-family: Arial; color: black;", 
                                  opacity=0.8, 
                                  direction='top')
).add_to(results_map_protests)
results_map_protests.add_child(colormap) #adding legend to map


results_map_protests.save('results_map_protests.html')
display(HTML("<h1><a href='results_map_income.html' target='_blank'>results_map_income (Ctrl+Click)</a></h1>"))

results_map_protests
# Out:
# <h1><a href='results_map_income.html' target='_blank'>results_map_income (Ctrl+Click)</a></h1>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Is there any correlation between number of protests and other statistics?

# %%
#Getting number of protests per country without any threshold
number_of_protests_per_country = protests_df.groupby(['Country Code']).size().reset_index(name='protests count')

# %%
#Extracting the two column we are interesting in
country_by_income_2017_filtered=country_by_income_2017[['Country Code','Income Group']]

# %%
#joining tables to get the country, the income group and the protests count in the same table
income_group_and_protests_count=pd.merge(country_by_income_2017_filtered, number_of_protests_per_country, how='right', on=['Country Code'])
income_group_and_protests_count.head()
# Out:
#   Country Code  Income Group  protests count
# 0          ZWE           1.0               1
# 1          ZMB           3.0               1
# 2          YEM           1.0               1
# 3          PSE           3.0              98
# 4          VIR           6.0              64

# %%
countries_stats_with_code=pd.merge(countries_stats, country_codes_to_name, how='left', on='Country Name')
countries_stats_with_code=countries_stats_with_code.dropna()

# %%
#Getting a dataframe with all the statistics by country!
countries_all_stats=pd.merge(countries_stats_with_code, income_group_and_protests_count, how='left', on='Country Code')
countries_all_stats=countries_all_stats.dropna()
#Using countries that have more than 1 protest for the linear regression
countries_all_stats=countries_all_stats[countries_all_stats['protests count'] > 1]
countries_all_stats.head()
# Out:
#   Country Name                               Region  Population  \
# 0  Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1      Albania  EASTERN EUROPE                          3581655
# 4    Argentina              LATIN AMER. & CARIB        39921833
# 5      Armenia                 C.W. OF IND. STATES      2976372
# 7    Australia  OCEANIA                                20264082
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 4         2766890                        14.4                          0.18
# 5           29800                        99.9                          0.00
# 7         7686850                         2.6                          0.34
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 4           0.61                               15.18             11200.0
# 5          -6.47                               23.28              3500.0
# 7           3.98                                4.69             29000.0
#
#    Literacy (%)       ...        Other (%)  Climate  Birthrate  Deathrate  \
# 0          36.0       ...            87.65      1.0      46.60      20.34
# 1          86.5       ...            74.49      3.0      15.11       5.22
# 4          97.1       ...            87.21      3.0      16.73       7.55
# 5          98.6       ...            80.15      4.0      12.07       8.23
# 7         100.0       ...            93.41      1.0      12.14       7.51
#
#    Agriculture  Industry  Service  Country Code  Income Group  protests count
# 0        0.380     0.240    0.380           AFG           1.0            3538
# 1        0.232     0.188    0.579           ALB           4.0            3029
# 4        0.095     0.358    0.547           ARG           6.0            3160
# 5        0.239     0.343    0.418           ARM           4.0            3084
# 7        0.038     0.262    0.700           AUS           6.0            1459
#
# [5 rows x 23 columns]

# %% [markdown]
# In the dataframe above, we can access many statistics on each country such as density population, GDP (Gross Domestic Product), climate, birthrate, deathrate, infant mortality, etc. Thanks to all this available data, we can perform a linear regression to get an idea of the impact of each variable on the number of protests (stored in the dataframe too):

# %%
#Using linear regression to find impact of each variable on the protests count
feature_cols = ['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Net migration', 
                'Infant mortality (per 1000 births)', 'GDP ($ per capita)', 'Deathrate', 
                'Income Group', 'Phones (per 1000)', 'Climate', 'Birthrate',
                'Coastline (coast/area ratio)', 'Literacy (%)', 'Arable (%)', 'Crops (%)',
                'Arable (%)', 'Crops (%)']
X = countries_all_stats[feature_cols]
y = countries_all_stats['protests count']
logistic = LinearRegression()  # create the model
logistic.fit(X, y)  # train it
for f in range(len(feature_cols)):
    print("{0} * {1} + ".format(logistic.coef_[f], feature_cols[f]))
print(logistic.intercept_)
# Out:
# 5.8197651241481095e-06 * Population +
# 0.002472650153582089 * Area (sq. mi.) +
# -0.6644396393018378 * Pop. Density (per sq. mi.) +
# -57.53351725021716 * Net migration +
# 28.976893341944834 * Infant mortality (per 1000 births) +
# 0.19023111414326452 * GDP ($ per capita) +
# -468.54272881421326 * Deathrate +
# -1354.8503896765824 * Income Group +
# 27.99847739654623 * Phones (per 1000) +
# 1563.6847972081632 * Climate +
# 311.4469979057358 * Birthrate +
# -45.75017482687437 * Coastline (coast/area ratio) +
# -1.3915455631165174 * Literacy (%) +
# 53.04934220573078 * Arable (%) +
# -6.775211918587164 * Crops (%) +
# 53.04934220572435 * Arable (%) +
# -6.775211918586553 * Crops (%) +
# -8021.969834107391

# %% [markdown]
# # A list of internal milestones until Dec. 16
# <u>**29/11/2018:**</u> deadline for finding new statistics on the countries (already more than 20 but it could be interesting to find other variables to evaluate.
# <br><br>
# <u>**31/11/2018:**</u> doing the analysis on each country but depending on the year. Finding a way to visualize the evolution of the protests numbers year per year
# <br><br>
# <u>**02/12/2018:**</u> finding impact of each variables on the protests number on each country based on the year As we have the number of protests per year and statistics on each country per year, we should be able to see the influence of each variable. For instance, is a country increase a lot his GDP ($ per capita) and not the other variables, and the number of protests decrease we could assume that they are related, etc (that's just a simple example).
# <br><br>
# <u>**05/12/2018:**</u> we though about implementing a dynamic world map that show the protests days by days in a quick way (to help you understanding what we mean, here an example of the result we would like: https://www.globalforestwatch.org/map
# <br><br>
# <u>**08/12/2018:**</u> we got almost all the results we wanted, we wrote good comments and explanations. The documentation is well done. We choose the way to present our work: a 4-page PDF document or a data story in a platform like a blog post.
# <br><br>
# <u>**14/12/2018:**</u> We got all the result we wanted. Our visualizations are good. The report or the data story through a platform is done.
# <br><br>
# <u>**15/12/2018:**</u> Last verifications to verify everything.
